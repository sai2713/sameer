# %%
import pandas as pd

# %%
a=pd.read_csv("C:/Users/sai/Desktop/saipython/sai.csv",sep=',')
a
# Out:
#       SC_CODE       SC_NAME SC_GROUP SC_TYPE        OPEN       HIGH  \
# 0      500002  ABB LTD.           B        Q      869.85      898.0
# 1      500003  AEGIS LOGIS        A        Q      184.00      193.0
# 2      500008  AMAR RAJA BA       A        Q      700.00      713.0
# 3      500009  A.SARABHAI         X        Q       18.90       19.3
# 4      500010  HDFC               A        Q     1807.00     1809.4
# ...       ...           ...      ...     ...         ...        ...
# 3095   972713  IFCI150212A        F        B    10075.00    10298.9
# 3096   972715  IFCI150212C        F        B    10150.00    10150.0
# 3097   972720  IFCI310312B        F        B     4405.01     5099.0
# 3098   972759  940CBOI            F        B  1061374.00  1061374.0
# 3099   972885  893PTCIF22A        F        B    10150.00    10150.0
#
#              LOW       CLOSE        LAST  PREVCLOSE  NO_TRADES  NO_OF_SHRS  \
# ...

# %%
a.std()
# Out:
# SC_CODE       1.118816e+05
# OPEN          3.953871e+04
# HIGH          3.954828e+04
# LOW           3.949427e+04
# CLOSE         3.949900e+04
# LAST          3.950326e+04
# PREVCLOSE     3.449259e+04
# NO_TRADES     4.431643e+03
# NO_OF_SHRS    1.744502e+06
# NET_TURNOV    7.956882e+07
# TDCLOINDI              NaN
# dtype: float64

# %%
a.columns
# Out:
# Index(['SC_CODE', 'SC_NAME', 'SC_GROUP', 'SC_TYPE', 'OPEN', 'HIGH', 'LOW',
#        'CLOSE', 'LAST', 'PREVCLOSE', 'NO_TRADES', 'NO_OF_SHRS', 'NET_TURNOV',
#        'TDCLOINDI'],
#       dtype='object')

# %%
a.describe()
# Out:
#              SC_CODE          OPEN          HIGH           LOW         CLOSE  \
# count    3100.000000  3.100000e+03  3.100000e+03  3.100000e+03  3.100000e+03
# mean   558588.394839  2.045121e+03  2.052192e+03  2.038194e+03  2.044596e+03
# std    111881.567297  3.953871e+04  3.954828e+04  3.949427e+04  3.949900e+04
# min    500002.000000  3.000000e-02  3.000000e-02  3.000000e-02  3.000000e-02
# 25%    514446.500000  1.218750e+01  1.253500e+01  1.198250e+01  1.212000e+01
# 50%    531853.000000  4.777500e+01  4.880000e+01  4.655000e+01  4.757500e+01
# 75%    539016.250000  2.622250e+02  2.689625e+02  2.600000e+02  2.638500e+02
# max    972885.000000  1.061374e+06  1.061374e+06  1.061374e+06  1.061374e+06
#
#                LAST     PREVCLOSE      NO_TRADES    NO_OF_SHRS    NET_TURNOV  \
# count  3.100000e+03  3.100000e+03    3100.000000  3.100000e+03  3.100000e+03
# mean   2.044952e+03  1.697128e+03     725.680000  1.220479e+05  1.133560e+07
# ...

# %%
a.groupby(["open","high","low","close"]).groups
a
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-5114b5e5a468> in <module>
# ----> 1 a.groupby(["open","high","low","close"]).groups
#       2 a
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    5808             group_keys=group_keys,
#    5809             squeeze=squeeze,
# -> 5810             observed=observed,
#    5811         )
#    5812
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated)
#     407                 sort=sort,
#     408                 observed=observed,
# --> 409                 mutated=self.mutated,
#     410             )
#     411
#
# ...

# %%
a.describe()
# Out:
#              SC_CODE          OPEN          HIGH           LOW         CLOSE  \
# count    3100.000000  3.100000e+03  3.100000e+03  3.100000e+03  3.100000e+03
# mean   558588.394839  2.045121e+03  2.052192e+03  2.038194e+03  2.044596e+03
# std    111881.567297  3.953871e+04  3.954828e+04  3.949427e+04  3.949900e+04
# min    500002.000000  3.000000e-02  3.000000e-02  3.000000e-02  3.000000e-02
# 25%    514446.500000  1.218750e+01  1.253500e+01  1.198250e+01  1.212000e+01
# 50%    531853.000000  4.777500e+01  4.880000e+01  4.655000e+01  4.757500e+01
# 75%    539016.250000  2.622250e+02  2.689625e+02  2.600000e+02  2.638500e+02
# max    972885.000000  1.061374e+06  1.061374e+06  1.061374e+06  1.061374e+06
#
#                LAST     PREVCLOSE      NO_TRADES    NO_OF_SHRS    NET_TURNOV  \
# count  3.100000e+03  3.100000e+03    3100.000000  3.100000e+03  3.100000e+03
# mean   2.044952e+03  1.697128e+03     725.680000  1.220479e+05  1.133560e+07
# ...

# %%
a.groupby(["SC_CODE","SC_NAME","OPEN","HIGH","LOW","CLOSE"]).groups
aa.drop(a.columns[[]], axis=1, inplace=True)
# Out:
#       SC_CODE       SC_NAME SC_GROUP SC_TYPE        OPEN       HIGH  \
# 0      500002  ABB LTD.           B        Q      869.85      898.0
# 1      500003  AEGIS LOGIS        A        Q      184.00      193.0
# 2      500008  AMAR RAJA BA       A        Q      700.00      713.0
# 3      500009  A.SARABHAI         X        Q       18.90       19.3
# 4      500010  HDFC               A        Q     1807.00     1809.4
# ...       ...           ...      ...     ...         ...        ...
# 3095   972713  IFCI150212A        F        B    10075.00    10298.9
# 3096   972715  IFCI150212C        F        B    10150.00    10150.0
# 3097   972720  IFCI310312B        F        B     4405.01     5099.0
# 3098   972759  940CBOI            F        B  1061374.00  1061374.0
# 3099   972885  893PTCIF22A        F        B    10150.00    10150.0
#
#              LOW       CLOSE        LAST  PREVCLOSE  NO_TRADES  NO_OF_SHRS  \
# ...

# %%
OPEN.DTYPE
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-f9e69c4a6018> in <module>
# ----> 1 OPEN.DTYPE
#
# NameError: name 'OPEN' is not defined

# %%
a.open.dtype()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-acd21b86808a> in <module>
# ----> 1 a.open.dtype()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'open'

# %%
a.dtype()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-4d5648172ed9> in <module>
# ----> 1 a.dtype()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
a.del(sc_type)
# Out:
#   File "<ipython-input-20-eea6002b4730>", line 1
#     a.del(sc_type)
#         ^
# SyntaxError: invalid syntax

# %%
high.dtypes()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-51775a6f2d89> in <module>
# ----> 1 high.dtypes()
#
# NameError: name 'high' is not defined

# %%
HIGH.dtypes()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-29b2e1691b15> in <module>
# ----> 1 HIGH.dtypes()
#
# NameError: name 'HIGH' is not defined

# %%
HIGH.dtype()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-b0fd81294395> in <module>
# ----> 1 HIGH.dtype()
#
# NameError: name 'HIGH' is not defined

# %%
HIGH.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-ef713a447028> in <module>
# ----> 1 HIGH.dtypes
#
# NameError: name 'HIGH' is not defined

# %%
a.groupby(["SC_CODE","SC_NAME","OPEN","HIGH","LOW","CLOSE"]).groups
a
# Out:
#       SC_CODE       SC_NAME SC_GROUP SC_TYPE        OPEN       HIGH  \
# 0      500002  ABB LTD.           B        Q      869.85      898.0
# 1      500003  AEGIS LOGIS        A        Q      184.00      193.0
# 2      500008  AMAR RAJA BA       A        Q      700.00      713.0
# 3      500009  A.SARABHAI         X        Q       18.90       19.3
# 4      500010  HDFC               A        Q     1807.00     1809.4
# ...       ...           ...      ...     ...         ...        ...
# 3095   972713  IFCI150212A        F        B    10075.00    10298.9
# 3096   972715  IFCI150212C        F        B    10150.00    10150.0
# 3097   972720  IFCI310312B        F        B     4405.01     5099.0
# 3098   972759  940CBOI            F        B  1061374.00  1061374.0
# 3099   972885  893PTCIF22A        F        B    10150.00    10150.0
#
#              LOW       CLOSE        LAST  PREVCLOSE  NO_TRADES  NO_OF_SHRS  \
# ...

# %%
a.drop(a.columns[[LAST]],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-3301bac0ce04> in <module>
# ----> 1 a.drop(a.columns[[LAST]],inplace=True)
#
# NameError: name 'LAST' is not defined

# %%
a.Columns = ["OPEN","LAST","HIGH","CLOSE"]

# %%
a
# Out:
#       SC_CODE       SC_NAME SC_GROUP SC_TYPE        OPEN       HIGH  \
# 0      500002  ABB LTD.           B        Q      869.85      898.0
# 1      500003  AEGIS LOGIS        A        Q      184.00      193.0
# 2      500008  AMAR RAJA BA       A        Q      700.00      713.0
# 3      500009  A.SARABHAI         X        Q       18.90       19.3
# 4      500010  HDFC               A        Q     1807.00     1809.4
# ...       ...           ...      ...     ...         ...        ...
# 3095   972713  IFCI150212A        F        B    10075.00    10298.9
# 3096   972715  IFCI150212C        F        B    10150.00    10150.0
# 3097   972720  IFCI310312B        F        B     4405.01     5099.0
# 3098   972759  940CBOI            F        B  1061374.00  1061374.0
# 3099   972885  893PTCIF22A        F        B    10150.00    10150.0
#
#              LOW       CLOSE        LAST  PREVCLOSE  NO_TRADES  NO_OF_SHRS  \
# ...

# %%
a[["SC_CODE","OPEN","HIGH","LOW","SC_NAME"]]
# Out:
#       SC_CODE        OPEN       HIGH         LOW       SC_NAME
# 0      500002      869.85      898.0      866.00  ABB LTD.
# 1      500003      184.00      193.0      180.70  AEGIS LOGIS
# 2      500008      700.00      713.0      695.30  AMAR RAJA BA
# 3      500009       18.90       19.3       18.55  A.SARABHAI
# 4      500010     1807.00     1809.4     1760.20  HDFC
# ...       ...         ...        ...         ...           ...
# 3095   972713    10075.00    10298.9    10075.00  IFCI150212A
# 3096   972715    10150.00    10150.0    10150.00  IFCI150212C
# 3097   972720     4405.01     5099.0     4405.01  IFCI310312B
# 3098   972759  1061374.00  1061374.0  1061374.00  940CBOI
# 3099   972885    10150.00    10150.0    10150.00  893PTCIF22A
#
# [3100 rows x 5 columns]

# %%
A.HEAD(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-548a9562f765> in <module>
# ----> 1 A.HEAD(10)
#
# NameError: name 'A' is not defined

# %%
a.head(10)
# Out:
#    SC_CODE       SC_NAME SC_GROUP SC_TYPE     OPEN     HIGH      LOW    CLOSE  \
# 0   500002  ABB LTD.           B        Q   869.85   898.00   866.00   895.00
# 1   500003  AEGIS LOGIS        A        Q   184.00   193.00   180.70   190.05
# 2   500008  AMAR RAJA BA       A        Q   700.00   713.00   695.30   708.25
# 3   500009  A.SARABHAI         X        Q    18.90    19.30    18.55    19.25
# 4   500010  HDFC               A        Q  1807.00  1809.40  1760.20  1782.85
# 5   500012  ANDHRA PETRO       X        Q    22.20    22.20    21.25    21.95
# 6   500013  ANSAL INFRAS       T        Q     3.95     4.15     3.92     3.92
# 7   500016  ARUNAHTEL          XT       Q     5.25     5.25     5.25     5.25
# 8   500020  BOM DYEING         A        Q    61.80    61.80    58.70    59.00
# 9   500023  ASIANHOTNR         B        Q    59.35    59.35    53.00    53.60
#
#       LAST  PREVCLOSE  NO_TRADES  NO_OF_SHRS   NET_TURNOV  TDCLOINDI
# ...

# %%
a["HIGH"]= a["SC_NAME"].str.find(sub, start) 
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-90ec86200d2b> in <module>
# ----> 1 a["HIGH"]= a["SC_NAME"].str.find(sub, start)
#       2 a
#
# NameError: name 'sub' is not defined

# %%
a.dropna(inplace = True)

# %%
a
# Out:
# Empty DataFrame
# Columns: [SC_CODE, SC_NAME, SC_GROUP, SC_TYPE, OPEN, HIGH, LOW, CLOSE, LAST, PREVCLOSE, NO_TRADES, NO_OF_SHRS, NET_TURNOV, TDCLOINDI]
# Index: []

# %%
a.sub ='er'
a
# Out:
# Empty DataFrame
# Columns: [SC_CODE, SC_NAME, SC_GROUP, SC_TYPE, OPEN, HIGH, LOW, CLOSE, LAST, PREVCLOSE, NO_TRADES, NO_OF_SHRS, NET_TURNOV, TDCLOINDI]
# Index: []

# %%
a
# Out:
# Empty DataFrame
# Columns: [SC_CODE, SC_NAME, SC_GROUP, SC_TYPE, OPEN, HIGH, LOW, CLOSE, LAST, PREVCLOSE, NO_TRADES, NO_OF_SHRS, NET_TURNOV, TDCLOINDI]
# Index: []

# %%
a[["SC_CODE","OPEN","HIGH","LOW","SC_NAME"]]
# Out:
# Empty DataFrame
# Columns: [SC_CODE, OPEN, HIGH, LOW, SC_NAME]
# Index: []

# %%
a.head(10)
a
# Out:
# Empty DataFrame
# Columns: [SC_CODE, SC_NAME, SC_GROUP, SC_TYPE, OPEN, HIGH, LOW, CLOSE, LAST, PREVCLOSE, NO_TRADES, NO_OF_SHRS, NET_TURNOV, TDCLOINDI]
# Index: []

# %%
a=pd.read_csv("C:/Users/sai/Desktop/saipython/sai.csv",sep=',')
a
# Out:
#       SC_CODE       SC_NAME SC_GROUP SC_TYPE        OPEN       HIGH  \
# 0      500002  ABB LTD.           B        Q      869.85      898.0
# 1      500003  AEGIS LOGIS        A        Q      184.00      193.0
# 2      500008  AMAR RAJA BA       A        Q      700.00      713.0
# 3      500009  A.SARABHAI         X        Q       18.90       19.3
# 4      500010  HDFC               A        Q     1807.00     1809.4
# ...       ...           ...      ...     ...         ...        ...
# 3095   972713  IFCI150212A        F        B    10075.00    10298.9
# 3096   972715  IFCI150212C        F        B    10150.00    10150.0
# 3097   972720  IFCI310312B        F        B     4405.01     5099.0
# 3098   972759  940CBOI            F        B  1061374.00  1061374.0
# 3099   972885  893PTCIF22A        F        B    10150.00    10150.0
#
#              LOW       CLOSE        LAST  PREVCLOSE  NO_TRADES  NO_OF_SHRS  \
# ...

# %%
a[["SC_CODE","OPEN","HIGH","LOW","SC_NAME"]]
# Out:
#       SC_CODE        OPEN       HIGH         LOW       SC_NAME
# 0      500002      869.85      898.0      866.00  ABB LTD.
# 1      500003      184.00      193.0      180.70  AEGIS LOGIS
# 2      500008      700.00      713.0      695.30  AMAR RAJA BA
# 3      500009       18.90       19.3       18.55  A.SARABHAI
# 4      500010     1807.00     1809.4     1760.20  HDFC
# ...       ...         ...        ...         ...           ...
# 3095   972713    10075.00    10298.9    10075.00  IFCI150212A
# 3096   972715    10150.00    10150.0    10150.00  IFCI150212C
# 3097   972720     4405.01     5099.0     4405.01  IFCI310312B
# 3098   972759  1061374.00  1061374.0  1061374.00  940CBOI
# 3099   972885    10150.00    10150.0    10150.00  893PTCIF22A
#
# [3100 rows x 5 columns]

# %%
a.head(10)
a
# Out:
#       SC_CODE       SC_NAME SC_GROUP SC_TYPE        OPEN       HIGH  \
# 0      500002  ABB LTD.           B        Q      869.85      898.0
# 1      500003  AEGIS LOGIS        A        Q      184.00      193.0
# 2      500008  AMAR RAJA BA       A        Q      700.00      713.0
# 3      500009  A.SARABHAI         X        Q       18.90       19.3
# 4      500010  HDFC               A        Q     1807.00     1809.4
# ...       ...           ...      ...     ...         ...        ...
# 3095   972713  IFCI150212A        F        B    10075.00    10298.9
# 3096   972715  IFCI150212C        F        B    10150.00    10150.0
# 3097   972720  IFCI310312B        F        B     4405.01     5099.0
# 3098   972759  940CBOI            F        B  1061374.00  1061374.0
# 3099   972885  893PTCIF22A        F        B    10150.00    10150.0
#
#              LOW       CLOSE        LAST  PREVCLOSE  NO_TRADES  NO_OF_SHRS  \
# ...

# %%
a.head(10)
# Out:
#    SC_CODE       SC_NAME SC_GROUP SC_TYPE     OPEN     HIGH      LOW    CLOSE  \
# 0   500002  ABB LTD.           B        Q   869.85   898.00   866.00   895.00
# 1   500003  AEGIS LOGIS        A        Q   184.00   193.00   180.70   190.05
# 2   500008  AMAR RAJA BA       A        Q   700.00   713.00   695.30   708.25
# 3   500009  A.SARABHAI         X        Q    18.90    19.30    18.55    19.25
# 4   500010  HDFC               A        Q  1807.00  1809.40  1760.20  1782.85
# 5   500012  ANDHRA PETRO       X        Q    22.20    22.20    21.25    21.95
# 6   500013  ANSAL INFRAS       T        Q     3.95     4.15     3.92     3.92
# 7   500016  ARUNAHTEL          XT       Q     5.25     5.25     5.25     5.25
# 8   500020  BOM DYEING         A        Q    61.80    61.80    58.70    59.00
# 9   500023  ASIANHOTNR         B        Q    59.35    59.35    53.00    53.60
#
#       LAST  PREVCLOSE  NO_TRADES  NO_OF_SHRS   NET_TURNOV  TDCLOINDI
# ...

# %%
print(list(a.columns))
# Out:
# ['SC_CODE', 'SC_NAME', 'SC_GROUP', 'SC_TYPE', 'OPEN', 'HIGH', 'LOW', 'CLOSE', 'LAST', 'PREVCLOSE', 'NO_TRADES', 'NO_OF_SHRS', 'NET_TURNOV', 'TDCLOINDI']
